# %%
#Negative Indexing
thislist = ["apple", "banana", "cherry"]
print(thislist[-1])
# Out:
# cherry

# %%
#to Print the number of items in the list
thislist = ["apple", "banana", "cherry"]
print(len(thislist))
# Out:
# 3

# %%
list1 = ["apple", "banana", "cherry"]
list2 = [1, 5, 7, 9, 3]
list3 = [True, False, False]
print(list1)
print (type(list2))
# Out:
# ['apple', 'banana', 'cherry']
# <class 'list'>

# %%
#Using the list() constructor to make a List:
thislist = list(("apple", "banana", "cherry")) # note the double round-brackets
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist=list(("apple","banana","cherry"))
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
#Access Items
thislist = ["apple", "banana", "cherry"]
print(thislist[1])
# Out:
# banana

# %%
thislist=["apple","banana","cherry"]
print(thislist[1])
print(thislist[2])
# Out:
# banana
# cherry

# %%
#Negitive Indexing
print(thislist[-1])
print(thislist[-2])
print(thislist[-3])
# Out:
# cherry
# banana
# apple

# %%
#range of indexes
thislist=["appple","banana","cherry","orange","mango","kiwi","melon"]
print(thislist[0:5])
print(thislist)
print(thislist[-4:-2])
print(thislist[1+3])
# Out:
# ['appple', 'banana', 'cherry', 'orange', 'mango']
# ['appple', 'banana', 'cherry', 'orange', 'mango', 'kiwi', 'melon']
# ['orange', 'mango']
# mango

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[:4])
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[-4:-1])
# Out:
# ['orange', 'kiwi', 'melon']

# %%
#Check if Item Exists
thislist3=["apple","banana","cherry"]
if "apple" in thislist3:
  print("Yes,'apple'is in the fruit set")
# Out:
# Yes,'apple'is in the fruit set

# %%
#Change the second item:
thislist4=["apple","banana","cherry"]
thislist4[2]="black currant "
print(thislist4)
# Out:
# ['apple', 'banana', 'black currant ']

# %%
#Change a Range of Item Values
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[1:3] = ["blackcurrant", "watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'orange', 'kiwi', 'mango']

# %%
#Change the second value by replacing it with two new values:
thislist = ["apple", "banana", "cherry"]
thislist[1:2] = ["blackcurrant", "watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'cherry']

# %%
#Change the second and third value by replacing it with one value:

thislist = ["apple", "banana", "cherry"]
thislist[1:3] = ["watermelon"]
print(thislist)
# Out:
# ['apple', 'watermelon']

# %%
#insert items
thislist=["apple","banana","cherry"]
thislist.insert(2,"watermelon ")
print(thislist)
# Out:
# ['apple', 'banana', 'watermelon ', 'cherry']

# %%
#To add an item to the end of the list
thislist = ["apple", "banana", "cherry"]
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist = ["apple","banana","cherry"]
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
#To append elements from another list to the current list
thislist = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]
thislist.extend(tropical)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']

# %%
#Remove Specified Item
thislist = ["apple", "banana", "cherry"]
thislist.remove("banana")
print(thislist)
# Out:
# ['apple', 'cherry']

# %%
thislist = ["banana", "apple", "banana", "cherry"]
thislist.remove("banana")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
#Remove the first item:
thislist = ["apple", "banana", "cherry"]
del thislist[1]
print(thislist)
# Out:
# ['apple', 'cherry']

# %%
#Delete the entire list:
thislist = ["apple", "banana", "cherry"]
del thislist
# print(thislist) # This line would cause a NameError as thislist is deleted

# %%
#Clear the list content:
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist)
# Out:
# []

# %%
#case1:list items by using a for loop: for loop having value with membership operator
thislist = ["apple", "banana", "cherry"]
for x in thislist:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
#case2:For loop having Index value
thislist = ["apple", "banana", "cherry"]
for i in range(len(thislist)):
  print(thislist)
# Out:
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry']

# %%
##C3: While loop using Index value
thislist = ["apple", "banana", "cherry"]
i = 0
while i < len(thislist):
  print(thislist[i])
  i = i + 1
# Out:
# apple
# banana
# cherry

# %%
#list comprension
thislist = ["apple", "banana", "cherry"]
for x in thislist:
 print(x)
# Out:
# apple
# banana
# cherry

# %%
thislist = ["apple", "banana", "cherry"]
[print(x) for x in thislist] #shorthend
# Out:
# apple
# banana
# cherry
# [None, None, None]

# %%
def show_message():
  print("hello")

# %%
value = show_message()
print(value)
# Out:
# hello
# None

# %%
#without comprehension
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = []

for x in fruits:
  if "a" in x:
    newlist.append(x)

print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
#with list comprehnsion
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]

newlist = [x for x in fruits if "a" in x]

print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
# sort list ascending
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort()
print(thislist)
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']

# %%
#descending
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort(reverse = True)
print(thislist)
# Out:
# ['pineapple', 'orange', 'mango', 'kiwi', 'banana']

# %%
#Make a copy of a list with the copy() method:
thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
#another way
thislist = ["apple", "banana", "cherry"]
mylist = list(thislist)
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
 #list by using the : (slice) operator.
 thislist = ["apple", "banana", "cherry"]
mylist = thislist[:]
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
 #list by using the : (slice) operator.
 thislist = ["apple", "banana", "cherry"]
mylist = thislist[1:3]
print(mylist)
# Out:
# ['banana', 'cherry']

# %%
#1 Join Two Lists
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
# 2 Join Two Lists .extend()
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list1.extend(list2)
print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
# 3 Join Two Lists by for loop
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

for x in list2:
  list1.append(x)

print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
# 4 Join Two Lists by for loop
l1 = ["a", "b", "c"]
l2 = [1, 2, 3]

l1.extend(l2)
l3=l1.copy()
print(l3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
#pop()	Removes the element at the specified position

# %%
#Method	Description
append()	Adds an element at the end of the list
clear()	Removes all the elements from the list
copy()	Returns a copy of the list
count()	Returns the number of elements with the specified value
extend()	Add the elements of a list (or any iterable), to the end of the current list
index()	Returns the index of the first element with the specified value
insert()	Adds an element at the specified position
pop()	Removes the element at the specified position
remove()	Removes the first item with the specified value
reverse()	Reverses the order of the list
sort()	Sorts the list
