# %% [markdown]
# project outcome is map as per code opmisatim wrt to time and space compexity
#
# * analysing and cleaning data in python is crucial for achieving desired output along with optimisation

# %% [markdown]
# #Pandas - Analyzing DataFrames

# %% [markdown]
# #Viewing the Data
# One of the most used method for getting a quick overview of the DataFrame, is the **head()** method.
#
# The head() method returns the headers and a specified number of rows, starting from the top.

# %% [markdown]
# if no value is given then 1st five rows printed

# %%
#Get a quick overview by printing the first 10 rows of the DataFrame:

import pandas as pd

df = pd.read_csv('data.csv')

print(df.head(10))
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %% [markdown]
# There is also a tail() method for viewing the last rows of the DataFrame.
#
# The tail() method returns the headers and a specified number of rows, starting from the bottom.

# %%
#Print the last 5 rows of the DataFrame:

print(df.tail())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %% [markdown]
# #Info About the Data
# The DataFrames object has a method called info(), that gives you more information about the data set

# %%
#Print information about the data:

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None

# %% [markdown]
# #Types of attributes
# * 1.simple vs commposite
#
# simple-->
#
# composite-->Name(1st,middle,last)
# * 2.single-valued vs multi valued
#
# SV--> Roll no
# MV-->mobile no
# * 3.NULL valued
#
# * 4.stored Vs desired
#
# stored-->data of birth
#
# d-->age
# * 5.complex

# %% [markdown]
# data cleaning consist of normalising te data wrt
# * A empty cells
# * B wrong data
# * removing duplicates

# %% [markdown]
# in data csv file calories parameter remaing 5 values mentioned as NAN

# %% [markdown]
# ex of data cleaning-emal consists@ symbo,mobile no 10 digit ,pin code 6digit
